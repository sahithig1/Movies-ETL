# %%
pip install psycopg2
# Out:
# ...
#   Using cached psycopg2-2.9.3.tar.gz (380 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /Users/satya/opt/anaconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/xv/vcndt0815kx4sxrj4496vy440000gp/T/pip-install-0c_n888k/psycopg2_2ba54c015e3b40d9bf0b07b98b1bb885/setup.py'"'"'; __file__='"'"'/private/var/folders/xv/vcndt0815kx4sxrj4496vy440000gp/T/pip-install-0c_n888k/psycopg2_2ba54c015e3b40d9bf0b07b98b1bb885/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/xv/vcndt0815kx4sxrj4496vy440000gp/T/pip-pip-egg-info-yqw0ngt4
# ...

# %%
import json
import pandas as pd
import numpy as np

import re

from sqlalchemy import create_engine
import psycopg2

# %%
import config

# %%
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movie_data"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/movie_data"
#
# NameError: name 'db_password' is not defined

# %%
from config import db_password
from sqlalchemy import create_engine

import time
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 from config import db_password
#       2 from sqlalchemy import create_engine
#       4 import time
#
# ImportError: cannot import name 'db_password' from 'config' (/Users/satya/opt/anaconda3/lib/python3.9/site-packages/config/__init__.py)

# %%
# 1. Create a function that takes in three arguments;
# Wikipedia data, Kaggle metadata, and MovieLens rating data (from Kaggle)



def ETL_three_arg_func():
    # 2. Read in the kaggle metadata and MovieLens ratings CSV files as Pandas DataFrames.
    kaggle_metadata = pd.read_csv('movies_metadata.csv')
    ratings =pd.read_csv('ratings.csv')

    # 3. Open the read the Wikipedia data JSON file.
    #file_dir = wikipedia_movies.json
    
    # 4. Read in the raw wiki movie data as a Pandas DataFrame.
    with open('wikipedia_movies.json'):
        wiki_movies_raw = json.load(file)
        wiki_movies_df = pd.dataframe(wiki_movies_raw)
    
    # 5. Return the three DataFrames
    return wiki_movies_df, kaggle_metadata, ratings

# 6 Create the path to your file directory and variables for the three files. 
#file_dir = 'wikipedia_movies.json'
# Wikipedia data
wiki_file = 'wikipedia_movies.json'
# Kaggle metadata
kaggle_file = 'movies_metadata.csv'
# MovieLens rating data.
ratings_file = 'ratings.csv'

# 7. Set the three variables in Step 6 equal to the function created in Step 1.
wiki_file, kaggle_file, ratings_file = ETL_three_arg_func()
# Out:
# /var/folders/xv/vcndt0815kx4sxrj4496vy440000gp/T/ipykernel_11254/3195929290.py:23: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   kaggle_metadata = pd.read_csv('movies_metadata.csv')
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 47>()
#      44 ratings_file = 'ratings.csv'
#      46 # 7. Set the three variables in Step 6 equal to the function created in Step 1.
# ---> 47 wiki_file, kaggle_file, ratings_file = ETL_three_arg_func()
#
# Input In [6], in ETL_three_arg_func()
#      24 ratings =pd.read_csv('ratings.csv')
#      26 # 3. Open the read the Wikipedia data JSON file.
#      27 #file_dir = wikipedia_movies.json
#      28
#      29 # 4. Read in the raw wiki movie data as a Pandas DataFrame.
# ---> 30 with open('wikipedia_movies.json'):
#      31     wiki_movies_raw = json.load(file)
# ...

# %%
# 8. Set the DataFrames from the return statement equal to the file names in Step 6. 
wiki_movies_df = wiki_file
kaggle_metadata = kaggle_file
ratings = ratings_file

# %%
# 9. Check the wiki_movies_df DataFrame.
wiki_movies_df.head()

# %%
# 10. Check the kaggle_metadata DataFrame.
kaggle_metadata.head()

# %%
# 11. Check the ratings DataFrame.
ratings.head()
